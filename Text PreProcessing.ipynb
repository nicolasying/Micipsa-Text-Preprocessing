# %% [markdown]
# # Lemmatize Text

# %%
import spacy
from french_lefff_lemmatizer.french_lefff_lemmatizer import FrenchLefffLemmatizer
from spacy import displacy

l2 = FrenchLefffLemmatizer()

# %%
french_text_origin_path = "./french_text.txt"
french_lemmatized_path = "./french_lem.txt"

# %%
file = open(french_text_origin_path, mode='r', encoding="cp1252")
original = file.readlines()
file.close()

original_corrected = []
for para in original:
    original_corrected.append(para.replace('\"', ' \" '))

# %%
nlp = spacy.load('fr', n_threads=4)
#nlp.remove_pipe('parser')
nlp.remove_pipe('ner')
# Out:
# ('ner', <spacy.pipeline.EntityRecognizer at 0x7f6394147728>)

# %%
pos_mapping = {
    "SCONJ": 'csu',
    "PRON": 'pro',
    "VERB": 'v',
    "NUM": "n",
    "NOUN": "n",
    "AUX": "auxAvoir",
    "PUNCT": "ponctw",
    "DET": "det",
    "ADJ": "adj",
    "ADP": "prep",
    "PROPN": "np",
    "ADV": "adv",
    'SPACE': ' ',
    'CCONJ': 'cc',
    '': '',
    'INTJ': 'intj',
    'PART': '',
    'X': ''
}

def lem_selector(text, pos_, dep_, doc):
    lem = l2.lemmatize(text, pos_mapping[pos_])
    if pos_ == 'PUNCT':
        res = '__punctuation__'
    elif isinstance(lem, str):
        res = lem + '_' + pos_mapping[token.pos_]
    elif isinstance(lem, tuple):
        res = lem[0] + '_' + lem[1]
    elif len(lem) == 0:
        return '\n'
    elif len(lem) == 1:
        res = lem[0][0] + '_' + lem[0][1]
    elif pos_ == 'PRON':
        res = '__PRONOUN__'
    elif pos_ == 'AUX' or dep_ == 'aux':
        res = '__AUXILARY__'
    elif pos_ == 'CCONJ':
        res = '__CCONJ__'
    elif pos_ == 'ADV':
        return lem_selector(text, 'VERB', dep_, doc)
    else:
        res = '__UNRESOLVED__' 
        #print(text, pos_, dep_, lem, doc)
    
    return res + '__origin' + text

# %%
output_file = open(french_lemmatized_path, mode='w+')
for para in original_corrected:
    doc = nlp(para)
    res = []
    for token in doc:
        res.append(lem_selector(token.text, token.pos_, token.dep_, doc.text))
    #print(' '.join(res))    
    output_file.write(' '.join(res))
    
output_file.close()

# %% [markdown]
# # Obtain Vocabulary - LPP

# %%
file = open(french_lemmatized_path, mode='r')
original = file.readlines()
file.close()

# %%
vocabulary = {}

def vocabulary_updater(word_pos, vocabulary=vocabulary):
    if word_pos in vocabulary:
        vocabulary[word_pos] += 1
    else:
        vocabulary[word_pos] = 1

# %%
for para in original:
    data = para.strip().split(' ')
    for token in data:
        word_parse = token.split('__origin')
        vocabulary_updater(word_parse[0])

# %%
word_list = [k for k in sorted(vocabulary, key=vocabulary.get, reverse=True)]

# %%
overwrite_check = False

if overwrite_check:
    output_file = open('vocabulary_pos_lpp.txt', mode='w+')

    for word in word_list:
        output_file.write(word + ';' + str(vocabulary[word]) + '\n');

    output_file.close()

# %% [markdown]
# # Vocabulary Intersection with WOLF

# %%
file = open('./vocabulary_pos_wolf.txt')
vocabulary_wolf = file.read()
vocabulary_wolf = set(vocabulary_wolf.split('\n'))

# %%
vocabulary_lpp = set(vocabulary.keys())

# %%
freq_accounted = 0
for word in vocabulary_lpp.intersection(vocabulary_wolf):
    freq_accounted += vocabulary[word]

# %%
freq_unaccounted = 0
for word in vocabulary_lpp.difference(vocabulary_wolf):
    freq_unaccounted += vocabulary[word]

# %%
freq_accounted, freq_unaccounted
# Out:
# (4408, 14869)

# %% [markdown]
# ## LPP POS Tag Analyse

# %%
lpp_pos_dict = dict()

for entry in vocabulary_lpp:
    try:
        word, pos = entry.rsplit('_', 1)
    except:
        print('Error', entry)    
        continue
    if pos not in lpp_pos_dict:
        lpp_pos_dict[pos] = set()
        lpp_pos_dict[pos].add(word)
    else:
        lpp_pos_dict[pos].add(word)
# Out:
# Error
# Error États-Unis

# %%
lpp_pos_dict.keys()
# Out:
# dict_keys(['v', 'nc', 'n', 'adj', 'np', 'adv', 'clneg', 'prep', 'pro', 'coo', 'det', 'csu', 'auxAvoir', '', 'advneg', 'prel', 'cln'])

# %%
pos_wolf_map = {
    "adv": "b",
    "adj": "a",
    "np": "n",
    "nc": "n",
    "n": "n",
    "v": 'v',
}

functional_pos_set = {'prep', 'coo', 'auxAvoir', 'det', 'clneg', 
                      'csu', 'pro', 'advneg', 'cln', 'prel'}

def fuzzy_match(word_included, vocabulary_including):
    if word_included[:2] == "__":
        return '__GIVEN_FUNCTIONAL__'
    try:
        word, pos = word_included.rsplit('_', 1)
    except:
        print('Error splitting', word_included)
        return False
    if pos in functional_pos_set:
        return '__MATCHED_FUNCTIONAL__'
    else:
        try:
            pos = pos_wolf_map[pos]
        except:
            print('Unknown pos tag', pos, word)
        if word in vocabulary_including:
            return word
        else:
            word = word.lower() + '_' + pos
            if word in vocabulary_including:
                return word
            else:
                print('Unable to match', word_included)
                return False

# %%
to_match = [k for k in sorted(vocabulary_lpp.difference(vocabulary_wolf), key=vocabulary.get, reverse=True)]
unmatched_1 = set()
match_1 = dict()
for word in to_match:
    #print(word, fuzzy_match(word, vocabulary_wolf))
    res = fuzzy_match(word, vocabulary_wolf)
    if not res:
        unmatched_1.add(word)
    else:
        match_1[word] = res
# Out:
# Error splitting
# Unable to match falloir_v
# Unable to match allumeur_n
# Unable to match toi_n
# Unable to match Ah_n
# Unable to match bonhomme_n
# Unable to match Pourquoi_adv
# Unable to match t_n
# Unable to match yeux_n
# Unable to match attendre_v
# Unable to match personne_v
# Unable to match voilà_v
# Unable to match pourquoi_adv
# Unable to match vaniteux_n
# Unable to match Celui-là_n
# Unable to match moutons_n
# Unable to match aurais_n
# Unable to match ramoner_v
# Unable to match géographe_v
# Unable to match suffit_n
# Unable to match conter_adv
# Unable to match Parce_np
# Unable to match seras_n
# Unable to match muselière_n
# Unable to match hem_n
# Unable to match Lui_np
# Unable to match qu'_adv
# Unable to match plaire_v
# Unable to match comprendre_adj
# Unable to match 612_n
# Unable to match Comment_adv
# Unable to match voici_v
# Unable to match drôle_v
# Unable to match oeil_n
# Unable to match grelot_n
# Unable to match éteint_n
# Unable to match tas_n
# Unable to match demanda_n
# Unable to match mienne_n
# Unable to match stupéfait_v
# Unable to match regarda_n
# Unable to match Dessine_np
# Unable to match Combien_adv
# Unable to match danger_v
# Unable to match mer_v
# Unable to match si_adv
# Unable to match écria_n
# Unable to match ajouta_n
# Unable to match France_np
# Unable to match tien_n
# Unable to match endormir_v
# Unable to match oublier_n
# Unable to match êtes_n
# Unable to match différent_adv
# Unable to match fais_n
# Unable to match vent_v
# Unable to match avais_n
# Unable to match pâle_v
# Unable to match conséquent_n
# Unable to match debout_n
# Unable to match sinon_adv
# Unable to match brusquement_v
# Unable to match t'_adv
# Unable to match cherche_n
# Unable to match joli_v
# Unable to match chapitrer_adv
# Unable to match au_n
# Unable to match ignorer_v
# Unable to match extraordinaire_n
# Unable to match Afrique_np
# Unable to match Faites_n
# Unable to match dit_adj
# Unable to match champs_n
# Unable to match réussir_n
# Unable to match lever_adv
# Unable to match décidément_v
# Unable to match répondis_n
# Unable to match faites_n
# Unable to match poliment_adv
# Unable to match valoir_v
# Unable to match répliquer_v
# Unable to match enquérir_v
# Unable to match Fais_n
# Unable to match irrité_n
# Unable to match entends_n
# Unable to match ton_adv
# Unable to match Noël_np
# Unable to match apprivoise_n
# Unable to match hâter_v
# Unable to match écrier_v
# Unable to match tellement_n
# Unable to match fier_n
# Unable to match auprès_adv
# Unable to match rejoindre_n
# Unable to match Allons_n
# Unable to match réussir_adv
# Unable to match majestueux_adj
# Unable to match m'as_n
# Unable to match illuminé_adj
# Unable to match autrefois_n
# Unable to match tombé_adj
# Unable to match soi-même_n
# Unable to match Hem_n
# Unable to match dessine_n
# Unable to match sire_n
# Unable to match confus_n
# Unable to match meurt_n
# Unable to match N'_adv
# Unable to match repartir_v
# Unable to match avouer_v
# Unable to match quarante-trois_n
# Unable to match joli_adj
# Unable to match dessin_v
# Unable to match paravent_nc
# Unable to match vole_n
# Unable to match Crois_n
# Unable to match objecter_v
# Unable to match feux_n
# Unable to match rallumer_n
# Unable to match avoir_adv
# Unable to match majestueusement_v
# Unable to match vu_adj
# Unable to match bois-tu_n
# Unable to match gagnes_n
# Unable to match là-dessus_n
# Unable to match tut_n
# Unable to match intimide_n
# Unable to match vexer_adv
# Unable to match désobéir_n
# Unable to match fripée_n
# Unable to match pacifique_n
# Unable to match Toi_np
# Unable to match gêne_n
# Unable to match compréhensif_adj
# Unable to match disais_n
# Unable to match aiguillage_n
# Unable to match riche_v
# Unable to match attacher_n
# Unable to match c'est-à-dire_n
# Unable to match Répéta_np
# Unable to match révélé_n
# Unable to match ah_n
# Unable to match paravent_n
# Unable to match comprendras_n
# Unable to match vexé_adj
# Unable to match entrevoir_v
# Unable to match éphémères_v
# Unable to match étrange_n
# Unable to match tellement_v
# Unable to match ravissante_n
# Unable to match bénie_n
# Unable to match enfuir_v
# Unable to match regrettes_n
# Unable to match faufiler_v
# Unable to match ajouté_adj
# Unable to match miser_v
# Unable to match indiscipline_n
# Unable to match reviendras_n
# Unable to match éveillé_n
# Unable to match aisément_v
# Unable to match ailler_v
# Unable to match glacer_v
# Error splitting États-Unis
# Unable to match Sibérie_np
# Unable to match au_v
# Unable to match Bonsoir_np
# Unable to match consolé_adj
# Unable to match parfait_v
# Unable to match perfore_n
# Unable to match perfectionné_adj
# Unable to match arrivé_n
# Unable to match soi£_n
# Unable to match revolver_v
# Unable to match clore_adj
# Unable to match trouves_n
# Unable to match piquet_n
# Unable to match inde_n
# Unable to match jolis_v
# Unable to match 329_n
# Unable to match confidence_n
# Unable to match pardon_v
# Unable to match instruire_v
# Unable to match choux_n
# Unable to match fidèle_v
# Unable to match respectueusement_v
# Unable to match regarderas_n
# Unable to match distingue_n
# Unable to match hésitant_n
# Unable to match coqueter_v
# Unable to match Va-t'en_np
# Unable to match haute_n
# Unable to match miennes_n
# Unable to match 11_n
# Unable to match entr'ouvertes_v
# Unable to match dérangea_n
# Unable to match 326_n
# Unable to match devinai_n
# Unable to match interroge_n
# Unable to match eft_v
# Unable to match chercher_n
# Unable to match crayonner_v
# Unable to match terribles_n
# Unable to match gentil_v
# Unable to match chauffer_n
# Unable to match tu_adj
# Unable to match Regardez_np
# Unable to match humilier_n
# Unable to match vieillir_v
# Unable to match 16_n
# Unable to match bâille_n
# Unable to match lampion_n
# Unable to match 25_n
# Unable to match chef-d'oeuvre_n
# Unable to match vends_n
# Unable to match commença_n
# Unable to match répondu_adj
# Unable to match contente_n
# Unable to match 328_n
# Unable to match marcheras_n
# Unable to match cache-nez_v
# Unable to match parles_n
# Unable to match dort_n
# Unable to match calcul_v
# Unable to match bizarre_n
# Unable to match Nouvelle-Zélande_np
# Unable to match Jupiter_np
# Unable to match évadé_adj
# Unable to match halte_v
# Unable to match margelle_n
# Unable to match deviens_n
# Unable to match connaissent_n
# Unable to match naïve_v
# Unable to match mange_n
# Unable to match 1909_n
# Unable to match Dis_np
# Unable to match digérer_v
# Unable to match rends_n
# Unable to match Exact_n
# Unable to match granit_n
# Unable to match Viens_n
# Unable to match cinquante-quatre_n
# Unable to match t'_v
# Unable to match tranquille_n
# Unable to match Quant_np
# Unable to match remord_n
# Unable to match lucide_adj
# Unable to match pleines_n
# Unable to match mince_n
# Unable to match vilain_adj
# Unable to match Soyez_np
# Unable to match tracer_v
# Unable to match étonné_adj
# Unable to match contradictoires_n
# Unable to match breveter_v
# Unable to match serrais_n
# Unable to match Pardonnez_np
# Unable to match Voulais_n
# Unable to match Voyons_n
# Unable to match crayon_v
# Unable to match redescendre_v
# Unable to match éloignée_n
# Unable to match Ordonnez_np
# Unable to match doré_n
# Unable to match comment_adv
# Unable to match Vécues_np
# Unable to match bâilla_n
# Unable to match Riposta_np
# Unable to match enjamber_v
# Unable to match sept._n
# Unable to match intrigué_adj
# Unable to match long_n
# Unable to match meeting_n
# Unable to match endort_n
# Unable to match Arizona_np
# Unable to match grand-chose_n
# Unable to match distraction_n
# Unable to match absurde_v
# Unable to match Rappela_np
# Unable to match condamneras_n
# Unable to match décrire_n
# Unable to match hasard_v
# Unable to match bredouiller_v
# Unable to match hocher_v
# Unable to match 325_n
# Unable to match rare_v
# Unable to match là-haut_v
# Unable to match Ben_v
# Unable to match orgueilleuse_v
# Unable to match escamoter_v
# Unable to match rayonnement_v
# Unable to match bonsoir_n
# Unable to match méditatif_adj
# Unable to match proie_v
# Unable to match explorateur_adj
# Unable to match regarde_n
# Unable to match soixante-douze_n
# Unable to match autrui_n
# Unable to match magnifique_n
# Unable to match Acheva_np
# Unable to match front_v
# Unable to match naïf_n
# Unable to match cambouis_n
# Unable to match raller_v
# Unable to match Admirer_np
# Unable to match i._v
# Unable to match roser_v
# Unable to match joli_n
# Unable to match Europe_np
# Unable to match impressionner_adv
# Unable to match intéressants_n
# Unable to match trouva_n
# Unable to match moi-même_n
# Unable to match 26_n
# Unable to match gracieras_n
# Unable to match retournais_n
# Unable to match verras_n
# Unable to match pensum_n
# Unable to match 1920_n
# Unable to match dévisser_v
# Unable to match démontage_n
# Unable to match émerveiller_v
# Unable to match idée_v
# Unable to match rapporte_n
# Unable to match tiennes_n
# Unable to match simplifié_adj
# Unable to match provision_n
# Unable to match connaître_n
# Unable to match éteints_n
# Unable to match aperçut_n
# Unable to match intelligent_n
# Unable to match brillent_n
# Unable to match gère_n
# Unable to match 24_n
# Unable to match recommença_n
# Unable to match Puis-je_np
# Unable to match réjouir_n
# Unable to match timidement_n
# Unable to match ronds_v
# Unable to match 18_n
# Unable to match aplomb_n
# Unable to match Tes_n
# Unable to match indulgence_n
# Unable to match petite_v
# Unable to match aimes_n
# Unable to match médité_n
# Unable to match assoiras_n
# Unable to match Justement_np
# Unable to match promène_n
# Unable to match ombrageux_adj
# Unable to match 3251_n
# Unable to match stylographe_n
# Unable to match 7_n
# Unable to match ascension_n
# Unable to match ressemblants_n
# Unable to match sienne_n
# Unable to match naïves_v
# Unable to match démoder_v
# Unable to match enfourner_v
# Unable to match modestement_v
# Unable to match recompte_n
# Unable to match baliverne_n
# Unable to match fis_n
# Unable to match mâcher_n
# Unable to match consolé_n
# Unable to match jolie_v
# Unable to match décoiffer_v
# Unable to match aiguiser_v
# Unable to match su_n
# Unable to match laid_v
# Unable to match éteins_n
# Unable to match Russie_np
# Unable to match redevenir_v
# Unable to match morde_n
# Unable to match bruire_v
# Unable to match admire_n
# Unable to match tienne_n
# Unable to match désirais_n
# Unable to match apercevais_n
# Unable to match puissant_v
# Unable to match croître_n
# Unable to match ralluma_n
# Unable to match e§t_v
# Unable to match Demandez_np
# Unable to match moraliste_n
# Unable to match contemplation_n
# Unable to match légère_n
# Unable to match habiterai_n
# Unable to match 6_n
# Unable to match ramena_n
# Unable to match combien_adv
# Unable to match pendant_adj
# Unable to match attendrir_v
# Unable to match Sûrement_v
# Unable to match faibles_v
# Unable to match travaux_n
# Unable to match 20_n
# Unable to match déconcerté_n
# Unable to match 9_n
# Unable to match lança_n
# Unable to match 22_n
# Unable to match vint_n
# Unable to match 330_n
# Unable to match demandai_n
# Unable to match interrogea_n
# Unable to match 27_n
# Unable to match occupe_n
# Unable to match réveille_n
# Unable to match interdis_n
# Unable to match là-bas_n
# Unable to match Reviens_n
# Unable to match d'Amérique_np
# Unable to match enrhumer_v
# Unable to match bâillant_n
# Unable to match Ah_adv
# Unable to match berçai_n
# Unable to match enfoui_n
# Unable to match horreur_v
# Unable to match Australie_np
# Unable to match honnête_n
# Unable to match réussis_n
# Unable to match possèdes_n
# Unable to match cherchons_n
# Unable to match mille_v
# Unable to match Hein_np
# Unable to match ensoleillée_n
# Unable to match vît_n
# Unable to match Vénus_np
# Unable to match 15_n
# Unable to match perdu_n
# Unable to match irréparable_n
# Unable to match éponger_v
# Unable to match Interrogea_n
# Unable to match embellir_v
# Unable to match brusquerie_n
# Unable to match insuccès_n
# Unable to match exigerai_n
# Unable to match Admire_n
# Unable to match 17_n
# Unable to match parlais_n
# Unable to match servir_n
# Unable to match numéro_v
# Unable to match étire_n
# Unable to match terribles_v
# Unable to match centaine_n
# Unable to match rassura_n
# Unable to match sorti_adj
# Unable to match Ouf_np
# Unable to match entendis_n
# Unable to match frôler_v
# Unable to match acclame_n
# Unable to match belles_v
# Unable to match rougissant_n
# Unable to match regarder_adv
# Unable to match tâtonner_v
# Unable to match énormes_n
# Unable to match 327_n
# Unable to match allaient_n
# Unable to match isolé_n
# Unable to match agiterai_n
# Unable to match salée_n
# Unable to match aval_adj
# Unable to match raisonner_v
# Unable to match imposa_n

# %%
for word in match_1:
    freq_accounted += vocabulary[word]
    freq_unaccounted -= vocabulary[word]

# %%
freq_accounted, freq_unaccounted
# Out:
# (17687, 1590)

# %%
word = ''
unmatched_1.discard(word)
freq_accounted += vocabulary[word]
freq_unaccounted -= vocabulary[word]

numbers_list = ['11_n', '15_n', '16_n', '17_n', '18_n', '1909_n',
 '1920_n', '20_n', '22_n', '24_n', '25_n', '26_n', '27_n', '3251_n',
 '325_n', '326_n', '327_n', '328_n', '329_n', '330_n', '612_n',
 '6_n', '7_n', '9_n']
for word in numbers_list:
    unmatched_1.discard(word)
    freq_accounted += vocabulary[word]
    freq_unaccounted -= vocabulary[word]

# %%
freq_accounted, freq_unaccounted
# Out:
# (18517, 760)

# %%
built_vocabulary_lpp = vocabulary_lpp.intersection(vocabulary_wolf).union(match_1.keys())
built_vocabulary = vocabulary_lpp.intersection(vocabulary_wolf).union(match_1.values())

# %%
len(unmatched_1), len(built_vocabulary), len(built_vocabulary_lpp)
# Out:
# (438, 1283, 1395)

# %%
manual_match = {
    'pleines_n': 'plein_a', 'possèdes_n': 'posséder_v', 'pourquoi_adv': "pourquoi_n",
    'proie_v': 'proie_n', 'promène_n': 'promener_v', 'puissant_v': 'puissant_a', 'pâle_v': "pâle_a",
    "qu'_adv": "__MANUAL_REJ__", 'quarante-trois_n': "__MANUAL_REJ__", 'ralluma_n': 'rallumer_v', 'rallumer_n': 'rallumer_v', 'ramena_n': 'ramener_v', 'rapporte_n': 'rapporter_v', 'rare_v': 'rare_a', 'rassura_n': 'rassurer_v', 'ravissante_n': "ravissant_a", 'rayonnement_v': 'rayonnement_n', 'recommença_n': 'recommencer_v', 'regarda_n': 'regarder_v', 'regarde_n': 'regarder_v', 'regarder_adv': 'regarder_v', 'regarderas_n': 'regarder_v', 'regrettes_n': 'regretter_v', 'rejoindre_n': 'rejoindre_v',
    'remord_n': 'remords_n', 'rends_n': 'rendre_v', 'respectueusement_v': 'respectueusement_b', 'retournais_n': 'retourner_v',
    'reviendras_n': 'revenir_v', 'revolver_v': 'revolver_n', 'riche_v': 'riche_a', 'ronds_v': 'rond_a', 'roser_v': 'rose_n',
    'réjouir_n': 'réjouir_v', 'répondis_n': 'répondre_v', 'répondu_adj': 'répondre_v', 'réussir_adv': 'réussir_v', 'réussir_n': 'réussir_v',
    'réussis_n': 'réussir_v', 'réveille_n': 'se_réveiller_v', 'révélé_n': 'révéler_v',
    'salée_n': 'salé_a', 'sept._n': "__MANUAL_REJ__", 'seras_n': 'être_v', 'serrais_n': 'serrer_v', 'servir_n': "servir_v", 'si_adv': 'tellement_b',
    'sire_n': 'sir_n', 'soixante-douze_n': "__MANUAL_REJ__", 'soi£_n': 'soif_n',
    'sorti_adj': 'sortir_v', 'stupéfait_v': 'stupéfait_a', 'su_n': 'savoir_v',
    'suffit_n': 'suffire_v', "t'_adv": "__MANUAL_REJ__", "t'_v": "__MANUAL_REJ__",
    't_n': "__MANUAL_REJ__", 'tas_n': 'ta_n', 'tellement_n': "tellement_b", 'tellement_v': 'tellement_b', 'terribles_n': 'terrible_a', 'terribles_v': "terrible_a", 'tien_n': 'tenir_v', 'tienne_n': "__MANUAL_REJ__", 'tiennes_n': "__MANUAL_REJ__", 'timidement_n': 'timidement_b', 'toi_n': "__MANUAL_REJ__", 'tombé_adj': 'tomber_v', 'ton_adv': "__MANUAL_REJ__", 'tranquille_n': 'tranquille_a', 'travaux_n': 'travail_n', 'trouva_n': 'trouver_v', 'trouves_n': 'trouver_v', 'tu_adj': "__MANUAL_REJ__",
    'tut_n': 'se_taire_v', 'vaniteux_n': 'vaniteux_a', 'vends_n': 'vendre_v', 'vent_v': 'vent_n', 'verras_n': 'voir_v', 'vilain_adj': 'vilain_n', 'vint_n': 'venir_v', 'voici_v': 'voici_b', 'voilà_v': 'voici_b', 'vole_n': 'voler_v', 'vu_adj': 'voir_v', 'vît_n': 'voir_v', 'yeux_n': 'œil_n', 'États-Unis': "États-Unis_d'Amérique_n",
    'énormes_n': 'énorme_a', 'éphémères_v': 'éphémère_a', 'éteins_n': 'éteindre_v', 'éteint_n': 'éteindre_v',
    'éteints_n': 'éteindre_v', 'étire_n': 'étirer_v', 'étrange_n': 'étrange_a', 'éveillé_n': "éveiller_v", 'êtes_n': 'être_v',    "Acheva_np": "achever_v",    "Admire_n": "admirer_v",    "Admirer_np": "admirer_v",
    "Afrique_np": "Afrique_n",    "Allons_n": "aller_v",    "Arizona_np": "Arizona_n",
    "Australie_np": "Australie_n",    "Ah_n": "__MANUAL_REJ__",    "Ah_adv": "__MANUAL_REJ__",    "Ben_v": "__MANUAL_REJ__",    'Bonsoir_np': "bonjour_n",    'Celui-là_n': "__MANUAL_REJ__", 'Combien_adv': "__MANUAL_REJ__", 'Comment_adv': "__MANUAL_REJ__", 'Crois_n': "croire_v", 'Demandez_np': "demander_v", 'Dessine_np': "dessiner_v", 'Dis_np': "dire_v",
    'Europe_np': "Europe_n", 'Exact_n': 'exact_a', 'Fais_n': 'faire_v', 'Faites_n': 'faire_v', 'France_np': 'France_n', 'Hein_np': "__MANUAL_REJ__", 'Hem_n': "__MANUAL_REJ__",
    'Interrogea_n': "interroger_v", 'Jupiter_np': "Jupiter_n", 'Justement_np': 'justement_b', 'Lui_np': "__MANUAL_REJ__",
    "N'_adv": "__MANUAL_REJ__", 'Nouvelle-Zélande_np': "Nouvelle-Zélande_n",
    'Noël_np': 'Noël_n', 'Ordonnez_np': "ordonner_v", 'Ouf_np': "__MANUAL_REJ__", 'Parce_np': "__MANUAL_REJ__",
    'Pardonnez_np': "pardonner_v", 'Pourquoi_adv': "__MANUAL_REJ__",
    'Puis-je_np': "pouvoir_v", 'Quant_np': "__MANUAL_REJ__", 'Rappela_np': 'rappeler_v',
    'Regardez_np': 'regarder_v', 'Reviens_n': 'revenir_v', 'Riposta_np': "riposter_v", 'Russie_np': "Russie_n",
    'Répéta_np': 'répéter_v', 'Sibérie_np': 'Sibérie_n', 'Soyez_np': 'être_v', 'Sûrement_v': 'sûrement_b',
    'Tes_n': "__MANUAL_REJ__", 'Toi_np': "__MANUAL_REJ__", "Va-t'en_np": "aller_v", 'Viens_n': 'venir_v',
    'Voulais_n': 'vouloir_v', 'Voyons_n': 'voir_v', 'Vécues_np': 'vivre_v', 'Vénus_np': 'Vénus_n',
    'absurde_v': 'absurde_a', 'acclame_n': 'acclamer_v', 'admire_n': 'admirer_v', 'agiterai_n': 'agiter_v', 'ah_n': "__MANUAL_REJ__",
    'ailler_v': 'aller_v', 'aimes_n': 'aimer_v', 'aisément_v': 'aisément_b', 'ajouta_n': 'ajouter_v',
    'ajouté_adj': 'ajouter_v', 'allaient_n': 'aller_v', 'apercevais_n': 'apercevoir_v', 'aperçut_n': 'apercevoir_v',
    'apprivoise_n': 'apprivoiser_v', 'arrivé_n': 'arrivée_n', 'assoiras_n': 'asseoir_v',
    'attacher_n': 'attacher_v', 'attendre_v': 'attendre_avec_impatience_v',
    'au_n': "__MANUAL_REJ__", 'au_v': "__MANUAL_REJ__", 'auprès_adv': "__MANUAL_REJ__",
    'aurais_n': 'avoir_v', 'autrefois_n': 'autrefois_b', 'avais_n': 'avoir_v', 'aval_adj': "aval_n", 'avoir_adv': 'avoir_v', 'belles_v': 'beau_a',
    'bizarre_n': 'bizarre_a', 'bois-tu_n': 'boire_v', 'bonsoir_n': 'bon_après-midi_n',
    'brillent_n': 'briller_v', 'bruire_v': 'bruit_n', 'brusquement_v': 'brusquement_b',
    'bâilla_n': 'bâiller_v', 'bâillant_n': 'bâiller_v', 'bâille_n': 'bâiller_v',
    'bénie_n': 'bénir_v', "c'est-à-dire_n": "c'est-à-dire_b", 'calcul_v': 'calcul_n',
    'champs_n': 'champ_n', 'chapitrer_adv': 'chapitre_b', 'chauffer_n': 'chauffer_v',
    "chef-d'oeuvre_n": "chef-d'œuvre_n", 'cherche_n': "chercher_v", 'chercher_n': "chercher_v", 'cherchons_n': "chercher_v", 'choux_n': 'chou_n', 'cinquante-quatre_n': "__MANUAL_REJ__",
    'clore_adj': "clos_a", 'combien_adv': "__MANUAL_REJ__", 'comment_adv': "__MANUAL_REJ__", 'commença_n': 'commencer_v',
    'comprendras_n': 'comprendre_v', 'comprendre_adj': 'comprendre_v', 'condamneras_n': 'condamner_v',
    'confidence_n': 'confiance_n', 'confus_n': 'confus_a', 'connaissent_n': 'connaître_v', 'connaître_n': 'connaître_v',
    'consolé_adj': 'consoler_v', 'consolé_n': 'consoler_v', 'conséquent_n': 'conséquemment_b', 'contente_n': 'content_a',
    'conter_adv': 'content_a', 'contradictoires_n': 'contradictoire_a',
    'coqueter_v': 'coquet_a', 'crayon_v': 'crayon_n', 'croître_n': 'croître_b', "d'Amérique_np": "États-Unis_d'Amérique_n",
    'danger_v': 'danger_n', 'debout_n': 'debout_a', 'demanda_n': 'demander_v',
    'demandai_n': 'demander_v', 'dessin_v': 'dessin_n', 'dessine_n': 'dessiner_v', 'deviens_n': "devenir_v",
    'devinai_n': "deviner_v", 'différent_adv': 'différent_a', 'disais_n': 'dire_n',
    'distingue_n': 'distinguer_v', 'dit_adj': 'dire_v', 'dort_n': 'dormir_v',
    'doré_n': 'doré_a', 'drôle_v': 'drôle_a', 'décidément_v': 'décidément_b',
    'décrire_n': 'décrire_v', 'dérangea_n': "déranger_v", 'désirais_n': "désirer_v",
    'désobéir_n': "désobéir_v", 'eft_v': 'être_v', 'enjamber_v': 'enjambée_n',
    'ensoleillée_n': 'ensoleillé_a', 'endort_n': "s'endormir_v", 'endormir_v': "s'endormir_v", 'entendis_n': 'entendre_v', 'entends_n': 'entendre_v',
    'enfoui_n':    "s'enfuir_v",    'enfuir_v': "s'enfuir_v", "entr'ouvertes_v": 'entrouvert_a', 'exigerai_n': 'exiger_v', 'explorateur_adj': 'explorateur_n',
    'extraordinaire_n': 'extraordinaire_a', 'e§t_v': 'être_v', 'faibles_v': 'faible_a', 'fais_n': 'faire_v',
    'faites_n': 'faire_v', 'feux_n': 'feu_n', 'fidèle_v': 'fidèle_a',
    'fier_n': 'fier_a', 'fis_n': "répondre_v", 'front_v': 'front_n', 'gagnes_n': 'gagner_v',
    'gentil_v': 'gentil_a', 'glacer_v': 'glacé_a', 'grand-chose_n': 'chose_n',
    'gère_n': 'gérer_v', 'géographe_v': 'géographe_n', 'gêne_n': 'gêner_v',
    'habiterai_n': 'habiter_v', 'halte_v': 'halte_n', 'hasard_v': 'hasard_n', 'haute_n': 'haut_a',
    'hem_n': "__MANUAL_REJ__", 'honnête_n': 'honnête_a', 'horreur_v': 'horreur_n',
    'humilier_n': 'humilier_v', 'hâter_v': 'se_hâter_v', 'hésitant_n': 'hésiter_v',
    'i._v': "__MANUAL_REJ__", 'idée_v': 'idée_n', 'imposa_n': 'imposer_v', 'impressionner_adv': 'impressionnant_a', 'inde_n': 'Inde_n',
    'intelligent_n': 'intelligent_a', 'interdis_n': 'interdire_v', 'interroge_n': 'interroger_v',
    'interrogea_n': 'interroger_v', 'intimide_n': 'intimider_v', 'intéressants_n': 'intéressant_a', 'isolé_n': 'isolé_a',
    'joli_adj': 'beau_a', 'joli_n': 'beau_a', 'joli_v': 'beau_a', 'jolie_v': 'beau_a', 'jolis_v': 'beau_a',
    'laid_v': 'laid_a', 'lança_n': 'lancer_v', 'lever_adv': 'lever_v',
    'long_n': 'long_a', 'là-bas_n': 'là-bas_b', 'là-dessus_n': 'là-dessus_b',
    'là-haut_v': 'là_b', "m'as_n": "__MANUAL_REJ__", 'magnifique_n': 'magnifique_a',
    'majestueusement_v': 'majestueusement_b', 'majestueux_adj': 'fier_a',
    'mange_n': 'manger_v', 'marcheras_n': 'marcher_v', 'mer_v': 'mer_n', 'meurt_n': 'mourir_v',
    'mienne_n': "__MANUAL_REJ__", 'miennes_n': "__MANUAL_REJ__", 'mille_v': 'mille_a',
    'mince_n': "mince_a", 'miser_v': 'mettre_v', 'modestement_v': 'modestement_b',
    'morde_n': 'mordre_v', 'moutons_n': 'mouton_n', 'mâcher_n': 'mâcher_v',
    'médité_n': 'méditer_v', 'naïf_n': 'naïf_a', 'naïve_v': 'naïf_a', 'naïves_v': 'naïf_a',
    'numéro_v': "numéro_n", 'occupe_n': "s'occuper_de_v", 'oeil_n': 'œil_n',
    'orgueilleuse_v': 'orgueilleuse_a', 'oublier_n': 'oublier_v', 'pacifique_n': 'Pacifique_n', 'pardon_v': 'pardon_n', 'parfait_v': 'parfait_a', 'parlais_n': 'parler_v', 'parles_n': 'parler_v', 'perdu_n': 'perdre_v',
    'perfore_n': 'perforer_v', 'personne_v': 'personne_n', 'petite_v': 'petit_a',
}

# %%
"terrible_a" in vocabulary_wolf
# Out:
# True

# %%
manual_residual = {
 'aiguillage_n', 'aiguiser_v', 'allumeur_n', 'ascension_n', 
    'aplomb_n', 'attendrir_v', 'autrui_n', 'avouer_v', 'baliverne_n', 
    'bonhomme_n', 'bredouiller_v', 'berçai_n', 'brusquerie_n', 
    'cache-nez_v', 'cambouis_n', 'compréhensif_adj', 'breveter_v', 
    'centaine_n', 'contemplation_n', 'crayonner_v', 'distraction_n', 
    'digérer_v', 'démoder_v', 'démontage_n', 'dévisser_v', 'déconcerté_n',
    'décoiffer_v', 'embellir_v', 'enrhumer_v', 'enquérir_v', 
    'enfourner_v',  'escamoter_v', 'faufiler_v', 'fripée_n',
    "fripée_n", 'falloir_v', 'frôler_v', 'gracieras_n', 'entrevoir_v', 
    'granit_n', 'grelot_n', 'ignorer_v', 'hocher_v', 'indiscipline_n', 
    'illuminé_adj', 'instruire_v',  'insuccès_n', 'indulgence_n', 
    'irrité_n', 'intrigué_adj', 'lampion_n', 'irréparable_n', 
    'lucide_adj',  'meeting_n', 'légère_n', 'margelle_n', 'moi-même_n', 
    'moraliste_n',  'muselière_n', 'méditatif_adj', 'objecter_v', 
    'ombrageux_adj','paravent_n', 'pendant_adj', 'pensum_n', 
    'paravent_nc',  'piquet_n', 'perfectionné_adj', 'évadé_adj', 
    'plaire_v', 'poliment_adv', 'provision_n', 'raisonner_v', 
    'raller_v',  'ramoner_v', 'recompte_n', 'redescendre_v', 
    'repartir_v', 'redevenir_v',  'ressemblants_n', 'rougissant_n', 
    'répliquer_v', 'simplifié_adj', 'sienne_n', 'sinon_adv', 'soi-même_n',
    'stylographe_n', 'tracer_v', 'tâtonner_v', 'valoir_v', 'vexer_adv', 
    'vexé_adj', 'vieillir_v', 'écria_n', 'écrier_v', 'éloignée_n', 
    'émerveiller_v', 'éponger_v', 'étonné_adj'
}

# %%
len(manual_residual)
# Out:
# 98

# %%
freq_residual = 0
for word in manual_residual:
    freq_residual += vocabulary[word]

# %%
freq_residual
# Out:
# 181

# %%
built_vocabulary_lpp
# Out:
# {'éclater_v',
#  'monarque_nc',
#  'sauter_v',
#  'étonner_v',
#  'mauvais_n',
#  'forêt_n',
#  'entendre_v',
#  'certain_adj',
#  'trône_n',
#  'acte_n',
#  'ébaucher_v',
#  'orgueil_n',
#  'fleurir_v',
#  'pommier_n',
#  'étrange_adj',
#  'tirer_v',
#  'caisse_n',
#  'faible_adj',
#  'fou_n',
#  'baobab_n',
#  'miel_n',
#  'régulièrement_adv',
#  'chance_n',
#  'pâle_adj',
#  'brûler_v',
#  'cou_n',
#  'patience_n',
#  'ne_clneg',
#  'régler_v',
#  'croire_v',
#  'enrouler_v',
#  'sujet_n',
#  'fidèle_n',
#  'jeu_n',
#  'sorte_n',
#  'nord_n',
#  'chasseur_n',
#  'verser_v',
#  'modeste_adj',
#  'irriter_v',
#  'tourner_v',
#  'courage_nc',
#  'dangereux_adj',
#  'résoudre_v',
#  'débarrasser_v',
#  'efforcer_v',
#  'signifier_v',
#  'lumière_n',
#  'livre_n',
#  'mystère_n',
#  'frotter_v',
#  'décourager_v',
#  'ballet_n',
#  'consoler_v',
#  'milieu_n',
#  'nez_n',
#  'oreille_n',
#  'servir_v',
#  'année_n',
#  'rhume_n',
#  'évasion_n',
#  'outil_n',
#  'appeler_v',
#  'rapide_adj',
#  'admirateur_n',
#  'mètre_n',
#  'rayonner_v',
#  'urgence_n',
#  'rêver_v',
#  'aimer_v',
#  'confondre_v',
#  'vacance_n',
#  'souffrir_v',
#  'annoncer_v',
#  'cent_nc',
#  'tenir_v',
#  'animer_v',
#  'bruit_n',
#  'vivant_n',
#  'effort_n',
#  'apercevoir_v',
#  'louange_n',
#  'comme_adv',
#  'sauvage_n',
#  'voyager_v',
#  'tendresse_n',
#  'souffler_v',
#  'encore_adv',
#  'goutte_n',
#  'germer_v',
#  'royaume_n',
#  'résister_v',
#  'tonnerre_n',
#  'bouton_n',
#  'Pardon_np',
#  'hisser_v',
#  'sourire_v',
#  'soupirer_v',
#  'inconvénient_n',
#  'vent_n',
#  'émouvoir_v',
#  'enfant_n',
#  'changer_v',
#  'Astronomie_np',
#  'buveur_n',
#  'révéler_v',
#  'fabriquer_v',
#  'décider_v',
#  'feuille_n',
#  'découverte_n',
#  'surprendre_v',
#  'avant_prep',
#  'sur_prep',
#  'radis_n',
#  'anéantir_v',
#  'pain_n',
#  'B_np',
#  'seau_n',
#  'mémoire_n',
#  'découvrir_v',
#  'patient_n',
#  'fenêtre_n',
#  'de_prep',
#  'questionner_v',
#  'voler_v',
#  'course_n',
#  'rose_n',
#  'avoir_v',
#  'politique_n',
#  'hausser_v',
#  'courir_v',
#  'pas_adv',
#  'bizarre_adj',
#  'fois_n',
#  'nouveau_adj',
#  'rassurer_v',
#  'finir_v',
#  'prochain_adj',
#  'histoire_n',
#  'contraire_adj',
#  'utile_adj',
#  'ici_adv',
#  'manquer_v',
#  'sourire_n',
#  'rose_adj',
#  'pourtant_adv',
#  'afin_prep',
#  'cela_pro',
#  'abeille_n',
#  'définitivement_adv',
#  'lire_v',
#  'tout_adj',
#  'attache_n',
#  'risque_n',
#  'réparation_n',
#  'élégant_adj',
#  'ivrogne_n',
#  'corde_n',
#  'traiter_v',
#  'mécanicien_nc',
#  'court_adj',
#  'océan_n',
#  'boîte_n',
#  'entrer_v',
#  'banque_n',
#  'tempe_n',
#  'collection_n',
#  'seul_adj',
#  'lancer_v',
#  'abandonner_v',
#  'seulement_adv',
#  'trésor_n',
#  'puits_n',
#  'confrère_n',
#  'compte_n',
#  'oiseau_n',
#  'grave_adj',
#  'raconter_v',
#  'attention_n',
#  'possible_adj',
#  'condition_n',
#  'soigner_v',
#  'trou_n',
#  '21_n',
#  'portée_n',
#  'colombe_n',
#  'exécuter_v',
#  'celui-ci_pro',
#  'businessman_n',
#  'franc_n',
#  'foudre_n',
#  'chenille_n',
#  'cuir_n',
#  'naître_v',
#  'remarquer_v',
#  'cramoisi_adj',
#  'marteau_n',
#  'conseiller_v',
#  'donner_v',
#  'déjà_adv',
#  'durer_v',
#  'an_n',
#  'miraculeux_adj',
#  'révolution_n',
#  'pardonner_v',
#  'troisième_adj',
#  'géranium_n',
#  'sortir_v',
#  'tant_adv',
#  'sagesse_n',
#  'intelligence_n',
#  'gros_n',
#  'immobile_adj',
#  'demeurer_v',
#  'entraîner_v',
#  'grand_adj',
#  'ni_coo',
#  'science_n',
#  'bien_adv',
#  'atteindre_v',
#  'reproche_n',
#  'poule_n',
#  'avis_n',
#  'exister_v',
#  'apparition_n',
#  'décidément_adv',
#  'exemple_n',
#  'précis_adj',
#  'cause_n',
#  'poursuivre_v',
#  'ravissant_adj',
#  'poupée_n',
#  'naufragé_n',
#  'soupir_n',
#  'meilleur_adj',
#  'trouver_v',
#  'sens_n',
#  'golf_n',
#  'opinion_n',
#  'bâillement_n',
#  'B_n',
#  'merveilleux_adj',
#  'chose_n',
#  'premier_adj',
#  'mouton_n',
#  'perplexe_adj',
#  'mal_adv',
#  'noter_v',
#  'achever_v',
#  'gros_adj',
#  'depuis_prep',
#  'brusquement_adv',
#  'le_det',
#  'anneau_n',
#  'mépriser_v',
#  'jungle_n',
#  'nul_adj',
#  'injuste_adj',
#  'tomber_v',
#  'un_det',
#  'beauté_n',
#  'fidélité_n',
#  'frais_adj',
#  'soleil_n',
#  'pleurer_v',
#  'lune_n',
#  'métier_n',
#  'travers_n',
#  'installation_n',
#  'intérêt_n',
#  'lueur_n',
#  'maintenant_adv',
#  'église_n',
#  'dix_n',
#  'terre_n',
#  'remettre_v',
#  'langage_n',
#  'planète_n',
#  'sans_prep',
#  'rancune_n',
#  'venir_v',
#  'prêt_adj',
#  'fouiller_v',
#  'pencher_v',
#  'épuiser_v',
#  'peupler_v',
#  'saharien_n',
#  'toilette_n',
#  'aborder_v',
#  'trier_v',
#  'beau_adj',
#  'graine_n',
#  'étoile_n',
#  'soir_n',
#  'souvenir_n',
#  'mouche_n',
#  'sec_adj',
#  'peur_n',
#  'demain_adv',
#  'entrée_n',
#  'digestion_n',
#  'ancien_adj',
#  'quelconque_adj',
#  'préférer_v',
#  'manteau_n',
#  'taire_v',
#  'chapeau_n',
#  'mort_n',
#  'pensée_n',
#  'tranquille_adj',
#  'morsure_n',
#  'secouer_v',
#  'moquer_v',
#  'rouillé_adj',
#  'épargne_n',
#  'imagination_n',
#  'émouvant_adj',
#  'aliment_n',
#  'géographe_n',
#  'visite_n',
#  'paresseux_n',
#  'consigne_n',
#  'dépendre_v',
#  'Océan_np',
#  'jeune_adj',
#  'neuf_adj',
#  'respecter_v',
#  'réchauffer_v',
#  'pousse_n',
#  'tailler_v',
#  'Sud_np',
#  'fond_n',
#  'certain_det',
#  'arrosoir_n',
#  'ai_n',
#  'vide_n',
#  'considérable_adj',
#  'préambule_nc',
#  'partir_v',
#  'cheveu_n',
#  'ira_n',
#  'réfléchir_v',
#  'réflexion_n',
#  'jouer_v',
#  'aura_n',
#  'habiller_v',
#  'aiguilleur_n',
#  'cesser_v',
#  'Oui_np',
#  'ami_n',
#  'évidemment_adv',
#  'bouger_v',
#  'triste_adj',
#  'doigt_n',
#  'fermer_v',
#  'Honte_np',
#  'rester_v',
#  'ajouter_v',
#  'traîne_n',
#  'droite_n',
#  'quand_csu',
#  'quelquefois_adv',
#  'minuscule_n',
#  'lourd_n',
#  'étudier_v',
#  'rayonnement_n',
#  'sot_n',
#  'abord_n',
#  'Car_np',
#  'devenir_v',
#  'froid_adj',
#  'choquer_v',
#  'malheureux_adj',
#  'approche_n',
#  'but_n',
#  'frapper_v',
#  'monder_v',
#  'mélange_n',
#  'quelque_det',
#  'risquer_v',
#  'toujours_adv',
#  'commode_adj',
#  'chaque_det',
#  'marcher_v',
#  'six_n',
#  'sembler_v',
#  'lendemain_n',
#  'toux_n',
#  'par_n',
#  'responsable_adj',
#  'vert_adj',
#  'éléphant_n',
#  'Bonjour_np',
#  'champignon_n',
#  'mordre_v',
#  'région_n',
#  'sixième_adj',
#  'hanneton_n',
#  'échange_n',
#  'universel_n',
#  'population_n',
#  'brindille_nc',
#  'Dieu_np',
#  'négliger_v',
#  'Pas_adv',
#  'heureusement_adv',
#  'faim_n',
#  'autorité_n',
#  'décrire_v',
#  'dresser_v',
#  'coulisse_n',
#  'près_adv',
#  'avoir_auxAvoir',
#  'quitter_v',
#  'donc_adv',
#  'drôle_n',
#  'tour_n',
#  'papillon_n',
#  'rapide_n',
#  'respirer_v',
#  'dimension_n',
#  'souhaiter_v',
#  '12_n',
#  'moindre_adj',
#  'lui_pro',
#  'réussir_v',
#  '__PRONOUN__',
#  'fier_v',
#  'condamner_v',
#  'cinquième_adj',
#  'apprivoiser_v',
#  'effet_n',
#  'vanité_n',
#  'avec_prep',
#  'immensité_n',
#  'regretter_v',
#  'attentivement_adv',
#  'vigne_n',
#  'douze_n',
#  'bouche_n',
#  'vivre_v',
#  'visiter_v',
#  '__AUXILARY__',
#  'fatigant_adj',
#  'terrible_adj',
#  '23_n',
#  'Tu_n',
#  'bras_n',
#  'toucher_v',
#  'couleur_n',
#  'ruine_n',
#  'hum_n',
#  'hermine_n',
#  'milliard_n',
#  'crépuscule_n',
#  'malade_adj',
#  'scène_n',
#  'deviner_v',
#  'énormément_adv',
#  'rhumatisme_n',
#  'ridicule_adj',
#  'prix_n',
#  'vider_v',
#  'supporter_v',
#  'endroit_n',
#  'bonjour_n',
#  'important_adj',
#  'danser_v',
#  'juge_n',
#  'regard_n',
#  'tort_n',
#  'entasser_v',
#  'véritablement_adv',
#  'roc_nc',
#  '__CCONJ__',
#  'peser_v',
#  'guère_advneg',
#  'aveugle_adj',
#  'très_adv',
#  'sentiment_n',
#  'embaumer_v',
#  'doux_n',
#  'tâche_n',
#  'assez_adv',
#  'agir_v',
#  'importance_n',
#  'horreur_n',
#  'coeur_n',
#  'dormir_v',
#  'fermement_adv',
#  'et_coo',
#  'éruption_n',
#  'saluer_v',
#  'espèce_n',
#  'pays_n',
#  '__punctuation__',
#  'monde_n',
#  'européen_adj',
#  'écouter_v',
#  'pli_n',
#  'mieux_adv',
#  'éclat_n',
#  'Vierge_np',
#  'heure_n',
#  'forme_n',
#  'compter_v',
#  'volcan_n',
#  'entier_adj',
#  'camarade_n',
#  'vingt_n',
#  'rare_adj',
#  'idée_n',
#  'connaissance_n',
#  'aventure_n',
#  'jambe_n',
#  'musique_n',
#  'nombreux_adj',
#  '14_n',
#  'mouiller_v',
#  'rencontrer_v',
#  'pauvre_n',
#  'vie_n',
#  'avance_n',
#  'asseoir_v',
#  'unique_adj',
#  'griffe_n',
#  'point_n',
#  'roi_nc',
#  'simplicité_n',
#  'troupeau_n',
#  'lien_n',
#  'fête_n',
#  'faire_v',
#  'vas_n',
#  'serpent_nc',
#  'désirer_v',
#  'parfois_adv',
#  'placer_v',
#  'régner_v',
#  'ou_coo',
#  'secret_n',
#  'onze_nc',
#  'améliorer_v',
#  'pilule_n',
#  'te_n',
#  'blé_n',
#  'mesure_n',
#  'tout_pro',
#  '2_n',
#  'côté_n',
#  'dessin_n',
#  'revoir_v',
#  'parvenir_v',
#  'poche_n',
#  'visage_n',
#  'chiffon_n',
#  'expérience_n',
#  'Amérique_np',
#  'trois_n',
#  'loin_adv',
#  'eau_n',
#  'astéroïde_n',
#  'comme_prep',
#  'cadeau_n',
#  'part_n',
#  'jusque_prep',
#  'cent_n',
#  'tentative_n',
#  'longtemps_adv',
#  'chapitre_n',
#  'petit_adj',
#  'hâte_n',
#  'fée_n',
#  'durant_prep',
#  'dessiner_v',
#  'armée_n',
#  'casser_v',
#  'renoncer_v',
#  'jeudi_n',
#  'surveiller_v',
#  'refuser_v',
#  'lassitude_n',
#  'écorce_n',
#  'proposer_v',
#  'connaître_v',
#  'demi_n',
#  'coucher_v',
#  'défendre_v',
#  'ordre_n',
#  'couler_v',
#  'genre_n',
#  'nègre_adj',
#  'route_n',
#  'mèche_n',
#  'lui-même_pro',
#  'intéressant_adj',
#  'profiter_v',
#  'intriguer_v',
#  'puits_nc',
#  'arbre_n',
#  'remuer_v',
#  'humilier_v',
#  'fatigue_n',
#  'importer_v',
#  'bracelet_n',
#  'prince_n',
#  'éprouver_v',
#  'retenir_v',
#  'promener_v',
#  'mourir_v',
#  'chagrin_n',
#  "aujourd'hui_n",
#  'lentement_adv',
#  'mélancolie_n',
#  'personne_n',
#  'terminer_v',
#  'interrompre_v',
#  'preuve_n',
#  'déjeuner_v',
#  'seconde_adj',
#  'pied_n',
#  'fort_adj',
#  'invention_n',
#  'droit_n',
#  'pôle_n',
#  'debout_adj',
#  'bouteille_n',
#  'jeter_v',
#  'façon_n',
#  'convaincre_v',
#  'alors_adv',
#  'contenir_v',
#  'bonté_n',
#  'explorateur_n',
#  'orner_v',
#  'encombrant_adj',
#  'à_prep',
#  'exiger_v',
#  'comme_csu',
#  'ministre_n',
#  'ordinaire_adj',
#  'Sahara_n',
#  'espoir_n',
#  'monotone_adj',
#  'pourpre_n',
#  'parler_v',
#  'vraiment_adv',
#  'papier_n',
#  'amour_n',
#  'silence_n',
#  'rat_nc',
#  'mettre_v',
#  'reposer_v',
#  'rêverie_n',
#  'peu_adv',
#  'habit_n',
#  'paraître_v',
#  'paquet_n',
#  'raisonnement_n',
#  'songer_v',
#  'boa_nc',
#  'honte_nc',
#  'autre_adj',
#  'éteint_adj',
#  'minuit_n',
#  'brindille_n',
#  'cravate_n',
#  'prendre_v',
#  'revenir_v',
#  'enfin_adv',
#  'reprendre_v',
#  'donnée_n',
#  'traverser_v',
#  'main_n',
#  'différent_adj',
#  'mouchoir_n',
#  'vingt-deux_n',
#  'familier_adj',
#  'messe_n',
#  'chant_n',
#  'économie_n',
#  'serré_adj',
#  'larme_n',
#  'habitant_n',
#  'expert_n',
#  'précision_n',
#  'flâner_v',
#  'guide_n',
#  'compliqué_adj',
#  'général_n',
#  'apaiser_v',
#  'suffire_v',
#  'dernier_n',
#  'curieux_adj',
#  'tu_n',
#  'moins_adv',
#  'ville_n',
#  'carabine_n',
#  'Comme_adv',
#  'éclair_n',
#  'train_n',
#  'contact_n',
#  'obéir_v',
#  'question_n',
#  'empêcher_v',
#  'mentir_v',
#  'rang_n',
#  'fleur_n',
#  'craindre_v',
#  'discret_adj',
#  'temps_n',
#  'rien_pro',
#  'absurde_n',
#  'deux_n',
#  'favorable_adj',
#  'épouvantable_adj',
#  'numéro_nc',
#  'désert_n',
#  'rouge_adj',
#  'vouloir_v',
#  'pas_n',
#  'serrer_v',
#  'fusil_n',
#  'représenter_v',
#  'démonstration_n',
#  'éphémère_adj',
#  'cinq_n',
#  'répandre_v',
#  '19_n',
#  'secourir_v',
#  'rendez-vous_n',
#  'turc_adj',
#  'sept_n',
#  'père_n',
#  'montrer_v',
#  'businessman_nc',
#  'regret_n',
#  'absolument_adv',
#  'cabine_n',
#  'déçu_adj',
#  'chacun_pro',
#  'chaise_n',
#  'nom_n',
#  'courroie_n',
#  'que_adv',
#  'désobéissance_n',
#  'assister_v',
#  'dans_prep',
#  'faute_n',
#  'raison_n',
#  'peut-être_adv',
#  'boa_n',
#  'entourer_v',
#  'beaucoup_adv',
#  'pétale_n',
#  'soif_n',
#  'réverbère_n',
#  'attacher_v',
#  'soigneusement_adv',
#  'grandiose_adj',
#  'impitoyable_adj',
#  'vaste_adj',
#  'exception_n',
#  'change_n',
#  'nuit_n',
#  'gagner_v',
#  'fragile_adj',
#  'un_n',
#  'nouveau_n',
#  'moteur_n',
#  'époque_n',
#  'homme_n',
#  'pitié_nc',
#  'ciel_n',
#  'poulie_n',
#  'planète_nc',
#  'riche_adj',
#  'manteau_nc',
#  'bond_n',
#  'difficulté_n',
#  'Chapitre_np',
#  'rite_n',
#  'ainsi_adv',
#  'plutôt_adv',
#  'exercice_n',
#  'cependant_adv',
#  'paix_n',
#  'égarer_v',
#  'renard_nc',
#  'quarante_n',
#  'gonfler_v',
#  'copie_n',
#  'entretenir_v',
#  'jaune_adj',
#  'acheter_v',
#  'dune_n',
#  'quinze_nc',
#  'globe_n',
#  'imaginer_v',
#  'simple_adj',
#  'machine_n',
#  'montagne_n',
#  'plein_adj',
#  'cultiver_v',
#  'doucement_adv',
#  'tolérer_v',
#  'détenir_v',
#  'un_pro',
#  'gronder_v',
#  'bon_adj',
#  'savant_adj',
#  'oublier_v',
#  'éteindre_v',
#  'timidement_adv',
#  'instant_n',
#  'chute_n',
#  'éternel_adj',
#  'carrosse_n',
#  'vitre_n',
#  'soulever_v',
#  'long_adj',
#  'tigre_n',
#  'écrire_v',
#  'lampe_n',
#  'ms_det',
#  'arracher_v',
#  'fainéant_n',
#  'oisiveté_n',
#  'chasser_v',
#  '8_n',
#  'chanter_v',
#  'cueillir_v',
#  'huit_n',
#  'honte_n',
#  'haut_adj',
#  'rougir_v',
#  'cacher_v',
#  'poétique_adj',
#  'pendant_prep',
#  'coin_n',
#  'confier_v',
#  'arbuste_n',
#  'épine_n',
#  'erreur_n',
#  'vérité_n',
#  'fauve_n',
#  'tourmenter_v',
#  'racine_n',
#  'passant_n',
#  'vis_n',
#  'million_n',
#  'soucieux_adj',
#  'électricité_n',
#  'boulon_n',
#  'cheville_n',
#  'content_adj',
#  'moyen_n',
#  'mélancolique_adj',
#  'calcul_n',
#  'hasard_n',
#  'plante_n',
#  'enquête_n',
#  'simplement_adv',
#  'amusant_adj',
#  'mener_v',
#  'énorme_adj',
#  'aller_v',
#  'monotonie_n',
#  'ordonner_v',
#  'inverse_adj',
#  'coucher_n',
#  'flamme_n',
#  'devant_prep',
#  'travailler_v',
#  'lieu_n',
#  'leçon_n',
#  'causer_v',
#  'rentrer_v',
#  'plus_adv',
#  'tout_n',
#  'image_n',
#  'agacer_v',
#  'échapper_v',
#  'fatiguer_v',
#  'rire_n',
#  'tout_det',
#  'porter_v',
#  'lèvre_n',
#  'difficile_adj',
#  'registre_n',
#  'congrès_n',
#  'occuper_v',
#  'maladroit_adj',
#  'passer_v',
#  '1_n',
#  'vanter_v',
#  'rendre_v',
#  'Quinze_np',
#  'p_det',
#  'télescope_n',
#  'retrouver_v',
#  'malheureusement_adv',
#  'toit_n',
#  'voyage_n',
#  'catastrophe_n',
#  'quatre_n',
#  'village_n',
#  'taille_n',
#  'enfoncer_v',
#  'bonheur_n',
#  'consulter_v',
#  'bouteille_nc',
#  'mystérieux_adj',
#  'as_n',
#  'reste_n',
#  'gentil_n',
#  'trembler_v',
#  'crayon_n',
#  'devoir_v',
#  'sol_n',
#  '10_n',
#  'extraordinaire_adj',
#  'mauvais_adj',
#  'forcer_v',
#  'public_adj',
#  'second_n',
#  'marchand_n',
#  'table_n',
#  'occupation_n',
#  'venin_n',
#  'expédier_v',
#  'bélier_n',
#  'pierre_n',
#  'relever_v',
#  'trop_adv',
#  'raisonnable_adj',
#  'réparer_v',
#  'celui_pro',
#  'blé_nc',
#  'coup_n',
#  'semaine_n',
#  'écraser_v',
#  'préparer_v',
#  'modèle_n',
#  'géographe_nc',
#  'vers_prep',
#  'recommencer_v',
#  'moralité_n',
#  'invisible_adj',
#  'hors_prep',
#  'accord_n',
#  'rallumer_v',
#  'pire_adj',
#  'piloter_v',
#  'minute_n',
#  'danse_n',
#  'retourner_v',
#  'méchant_adj',
#  'couramment_adv',
#  'aiguille_n',
#  'portrait_n',
#  'journée_n',
#  'disparition_n',
#  'grammaire_n',
#  'quand_adv',
#  'si_csu',
#  'gouvernement_n',
#  'clef_n',
#  'en_prep',
#  'malheur_n',
#  'inquiéter_v',
#  'récit_n',
#  'distraire_v',
#  'moi_n',
#  'lugubre_adj',
#  '4_n',
#  'diamant_n',
#  'dur_adj',
#  'trente_n',
#  'genou_n',
#  'vent_nc',
#  'volonté_n',
#  'réserve_n',
#  'gauche_n',
#  'discipline_n',
#  'légende_n',
#  'désigner_v',
#  'semblable_adj',
#  'air_n',
#  'crise_n',
#  'armure_n',
#  'creuser_v',
#  'aussi_adv',
#  'douceur_n',
#  'ressembler_v',
#  'ensemble_n',
#  'univers_n',
#  'encombrer_v',
#  'chambre_n',
#  'arroser_v',
#  ...}

# %%
lpp_wolf_mapping = dict()

for word in vocabulary_lpp:
    if word in vocabulary_wolf:
        lpp_wolf_mapping[word] = word
    elif word in match_1:
        lpp_wolf_mapping[word] = match_1[word]
    elif word in manual_match:
        lpp_wolf_mapping[word] = manual_match[word]
    elif word in manual_residual:
        lpp_wolf_mapping[word] = '__UNMATECHED__'
    else:
        lpp_wolf_mapping[word] = '__MANUAL_REJ__'

# %% [markdown]
# ## Mapped frequency

# %%
wolf_freq = dict()
for origin in lpp_wolf_mapping:
    target = lpp_wolf_mapping[origin]
    if target not in wolf_freq:
        wolf_freq[target] = vocabulary[origin]
    else:
        wolf_freq[target] += vocabulary[origin]

# %%
[(k, wolf_freq[k]) for k in sorted(wolf_freq, key=wolf_freq.get, reverse=True)]
# Out:
# [('__GIVEN_FUNCTIONAL__', 6107),
#  ('__MATCHED_FUNCTIONAL__', 5176),
#  ('__MANUAL_REJ__', 953),
#  ('petit_a', 217),
#  ('dire_v', 194),
#  ('__UNMATECHED__', 181),
#  ('pas_b', 179),
#  ('prince_n', 171),
#  ('avoir_v', 119),
#  ('faire_v', 107),
#  ('bien_b', 98),
#  ('tu_n', 82),
#  ('planète_n', 66),
#  ('fleur_n', 66),
#  ('plus_b', 62),
#  ('répondre_v', 52),
#  ('très_b', 49),
#  ('étoile_n', 48),
#  ('alors_b', 47),
#  ('savoir_v', 46),
#  ('tout_a', 44),
#  ('voir_v', 43),
#  ('pouvoir_v', 43),
#  ('jamais_b', 42),
#  ('être_v', 41),
#  ('peu_b', 41),
#  ('personne_n', 40),
#  ('encore_b', 39),
#  ('mouton_n', 39),
#  ('là_b', 36),
#  ('roi_n', 36),
#  ('renard_n', 36),
#  ('grand_a', 35),
#  ('jour_n', 35),
#  ('vouloir_v', 34),
#  ('aussi_b', 33),
#  ('seul_a', 30),
#  ('tout_b', 30),
#  ('homme_n', 28),
#  ('trop_b', 28),
#  ('regarder_v', 27),
#  ('fois_n', 27),
#  ('venir_v', 27),
#  ('autre_a', 27),
#  ('comprendre_v', 27),
#  ('cent_n', 26),
#  ('chose_n', 26),
#  ('donc_b', 26),
#  ('ami_n', 24),
#  ('aller_v', 24),
#  ('toujours_b', 23),
#  ('dessin_n', 23),
#  ('chapitre_n', 23),
#  ('sûr_a', 23),
#  ('mille_n', 23),
#  ('croire_v', 22),
#  ('aimer_v', 22),
#  ('soleil_n', 22),
#  ('terre_n', 22),
#  ('demander_v', 22),
#  ('connaître_v', 22),
#  ('non_b', 22),
#  ('géographe_n', 21),
#  ('serpent_n', 21),
#  ('baobab_n', 20),
#  ('chercher_v', 20),
#  ('bonjour_n', 20),
#  ('sérieux_a', 20),
#  ('tellement_b', 19),
#  ('rose_n', 19),
#  ('nuit_n', 19),
#  ('dessiner_v', 18),
#  ('éteindre_v', 18),
#  ('cinq_n', 18),
#  ('beaucoup_b', 18),
#  ('réverbère_n', 18),
#  ('million_n', 18),
#  ('même_b', 18),
#  ('donner_v', 17),
#  ('beau_a', 17),
#  ('rire_v', 17),
#  ('trouver_v', 16),
#  ('apprivoiser_v', 16),
#  ('volcan_n', 16),
#  ('parler_v', 16),
#  ('désert_n', 16),
#  ('habiter_v', 15),
#  ('oui_n', 15),
#  ('ajouter_v', 15),
#  ('trois_n', 15),
#  ('posséder_v', 15),
#  ('boa_n', 15),
#  ('ainsi_b', 15),
#  ('ici_b', 14),
#  ('oublier_v', 14),
#  ('important_a', 14),
#  ('heure_n', 14),
#  ('asseoir_v', 14),
#  ('loin_b', 14),
#  ('œil_n', 14),
#  ('question_n', 14),
#  ('temps_n', 14),
#  ('deux_n', 14),
#  ('manger_v', 14),
#  ('servir_v', 13),
#  ('explorateur_n', 13),
#  ('six_n', 13),
#  ('vie_n', 13),
#  ('eau_n', 13),
#  ('longtemps_b', 13),
#  ('doucement_b', 13),
#  ('bon_a', 13),
#  ('moi_n', 13),
#  ('boire_v', 13),
#  ('entendre_v', 12),
#  ('apercevoir_v', 12),
#  ('déjà_b', 12),
#  ('an_n', 12),
#  ('cause_n', 12),
#  ('prendre_v', 12),
#  ('vaniteux_a', 12),
#  ('épine_n', 12),
#  ('ressembler_v', 12),
#  ('vieux_a', 12),
#  ('signifier_v', 11),
#  ('revenir_v', 11),
#  ('puits_n', 11),
#  ('premier_a', 11),
#  ('mort_n', 11),
#  ('voici_b', 11),
#  ('monde_n', 11),
#  ('air_n', 11),
#  ('sable_n', 11),
#  ('mettre_v', 10),
#  ('réussir_v', 10),
#  ('enfant_n', 10),
#  ('ordonner_v', 10),
#  ('businessman_n', 10),
#  ('taire_v', 10),
#  ('sembler_v', 10),
#  ('commencer_v', 10),
#  ('silence_n', 10),
#  ('peut-être_b', 10),
#  ('cependant_b', 10),
#  ('montagne_n', 10),
#  ('coucher_n', 10),
#  ('quatre_n', 10),
#  ('minute_n', 10),
#  ('maison_n', 10),
#  ('herbe_n', 10),
#  ('matin_n', 10),
#  ('peine_n', 10),
#  ('livre_n', 9),
#  ('histoire_n', 9),
#  ('maintenant_b', 9),
#  ('soir_n', 9),
#  ('peur_n', 9),
#  ('consigne_n', 9),
#  ('soif_n', 9),
#  ('couleur_n', 9),
#  ('dormir_v', 9),
#  ('coeur_n', 9),
#  ('idée_n', 9),
#  ('paraître_v', 9),
#  ('ciel_n', 9),
#  ('bâiller_v', 9),
#  ('répéter_v', 8),
#  ('suffire_v', 8),
#  ('content_a', 8),
#  ('tenir_v', 8),
#  ('bruit_n', 8),
#  ('buveur_n', 8),
#  ('marcher_v', 8),
#  ('tomber_v', 8),
#  ('pleurer_v', 8),
#  ('triste_a', 8),
#  ('abord_n', 8),
#  ('tour_n', 8),
#  ('unique_a', 8),
#  ('astéroïde_n', 8),
#  ('mourir_v', 8),
#  ('enfin_b', 8),
#  ('numéro_n', 8),
#  ('sept_n', 8),
#  ('attendre_avec_impatience_v', 8),
#  ('laisser_v', 8),
#  ('vrai_a', 8),
#  ('fait_n', 8),
#  ('sentir_v', 8),
#  ('place_n', 8),
#  ('besoin_n', 8),
#  ('juger_v', 8),
#  ('heureux_a', 8),
#  ('année_n', 7),
#  ('vent_n', 7),
#  ('découvrir_v', 7),
#  ('sortir_v', 7),
#  ('gros_a', 7),
#  ('interroger_v', 7),
#  ('graine_n', 7),
#  ('perdre_v', 7),
#  ('chapeau_n', 7),
#  ('aiguilleur_n', 7),
#  ('agir_v', 7),
#  ('point_n', 7),
#  ('part_n', 7),
#  ('coucher_v', 7),
#  ('ordre_n', 7),
#  ('importer_v', 7),
#  ('travail_n', 7),
#  ('que_b', 7),
#  ('poulie_n', 7),
#  ('globe_n', 7),
#  ('pourquoi_n', 7),
#  ('rire_n', 7),
#  ('1_n', 7),
#  ('voyage_n', 7),
#  ('coup_n', 7),
#  ('semblable_a', 7),
#  ('emporter_v', 7),
#  ('lever_v', 7),
#  ('apprendre_v', 7),
#  ('adieu_n', 7),
#  ('souvenir_v', 7),
#  ('avion_n', 7),
#  ('changer_v', 6),
#  ('surprendre_v', 6),
#  ('manquer_v', 6),
#  ('hasard_n', 6),
#  ('tant_b', 6),
#  ('exister_v', 6),
#  ('exemple_n', 6),
#  ('aura_n', 6),
#  ('fermer_v', 6),
#  ('bras_n', 6),
#  ('blé_n', 6),
#  ('faute_n', 6),
#  ('nouveau_n', 6),
#  ('arbuste_n', 6),
#  ('marchand_n', 6),
#  ('trente_n', 6),
#  ('tête_n', 6),
#  ('poser_v', 6),
#  ('ouvrir_v', 6),
#  ('même_a', 6),
#  ('es_n', 6),
#  ('monarque_n', 5),
#  ('tirer_v', 5),
#  ('utile_a', 5),
#  ('raconter_v', 5),
#  ('conseiller_v', 5),
#  ('durer_v', 5),
#  ('admirer_v', 5),
#  ('fier_a', 5),
#  ('poule_n', 5),
#  ('poursuivre_v', 5),
#  ('souvenir_n', 5),
#  ('exiger_v', 5),
#  ('habiller_v', 5),
#  ('responsable_a', 5),
#  ('éléphant_n', 5),
#  ('saluer_v', 5),
#  ('écouter_v', 5),
#  ('mieux_b', 5),
#  ('secret_n', 5),
#  ('cadeau_n', 5),
#  ('seconde_a', 5),
#  ('vraiment_b', 5),
#  ('main_n', 5),
#  ('vingt-deux_n', 5),
#  ('général_n', 5),
#  ('obéir_v', 5),
#  ('éphémère_a', 5),
#  ('mer_n', 5),
#  ('simple_a', 5),
#  ('rougir_v', 5),
#  ('difficile_a', 5),
#  ('passer_v', 5),
#  ('devoir_v', 5),
#  ('raisonnable_a', 5),
#  ('préparer_v', 5),
#  ('invisible_a', 5),
#  ('vite_b', 5),
#  ('danger_n', 5),
#  ('mal_n', 5),
#  ('mur_n', 5),
#  ('tard_b', 5),
#  ('Monsieur_n', 5),
#  ('ton_n', 5),
#  ('géographie_n', 5),
#  ('essayer_v', 5),
#  ('âge_n', 5),
#  ('mauvais_n', 4),
#  ('caisse_n', 4),
#  ('chance_n', 4),
#  ('consoler_v', 4),
#  ('extraordinaire_a', 4),
#  ('rapide_a', 4),
#  ('effort_n', 4),
#  ('comme_b', 4),
#  ('voyager_v', 4),
#  ('hésiter_v', 4),
#  ('b_n', 4),
#  ('voler_v', 4),
#  ('nouveau_a', 4),
#  ('corde_n', 4),
#  ('océan_n', 4),
#  ('crayon_n', 4),
#  ('vivre_v', 4),
#  ('oiseau_n', 4),
#  ('naître_v', 4),
#  ('remarquer_v', 4),
#  ("s'endormir_v", 4),
#  ('intéressant_a', 4),
#  ('noter_v', 4),
#  ('brusquement_b', 4),
#  ('différent_a', 4),
#  ('visite_n', 4),
#  ('jouer_v', 4),
#  ('honte_n', 4),
#  ('riche_a', 4),
#  ('quelquefois_b', 4),
#  ('car_n', 4),
#  ('devenir_v', 4),
#  ('région_n', 4),
#  ('brindille_n', 4),
#  ('quitter_v', 4),
#  ('drôle_n', 4),
#  ('papillon_n', 4),
#  ('exact_a', 4),
#  ('long_a', 4),
#  ('désirer_v', 4),
#  ('onze_n', 4),
#  ('revoir_v', 4),
#  ('poche_n', 4),
#  ('drôle_a', 4),
#  ('route_n', 4),
#  ('rallumer_v', 4),
#  ('mélancolie_n', 4),
#  ('preuve_n', 4),
#  ('ta_n', 4),
#  ('reposer_v', 4),
#  ('reprendre_v', 4),
#  ('montrer_v', 4),
#  ('calcul_n', 4),
#  ('imaginer_v', 4),
#  ('tigre_n', 4),
#  ('écrire_v', 4),
#  ('boulon_n', 4),
#  ('travailler_v', 4),
#  ('occuper_v', 4),
#  ('trembler_v', 4),
#  ('pierre_n', 4),
#  ('où_b', 4),
#  ('fontaine_n', 4),
#  ('rappeler_v', 4),
#  ('voix_n', 4),
#  ('garçon_n', 4),
#  ('reconnaître_v', 4),
#  ('or_n', 4),
#  ('ne_b', 4),
#  ('allumer_v', 4),
#  ('réveiller_v', 4),
#  ('penser_v', 4),
#  ('mot_n', 4),
#  ('apparaître_v', 4),
#  ('juste_b', 4),
#  ('plaisir_n', 4),
#  ('arriver_v', 4),
#  ('départ_n', 4),
#  ('tromper_v', 4),
#  ('recevoir_v', 4),
#  ('faible_a', 3),
#  ('pâle_a', 3),
#  ('gêner_v', 3),
#  ('attacher_v', 3),
#  ('sujet_n', 3),
#  ('chasseur_n', 3),
#  ('lumière_n', 3),
#  ('mystère_n', 3),
#  ('décourager_v', 3),
#  ('appeler_v', 3),
#  ('terrible_a', 3),
#  ('émouvoir_v', 3),
#  ('découverte_n', 3),
#  ('seau_n', 3),
#  ('bizarre_a', 3),
#  ('rassurer_v', 3),
#  ('ivrogne_n', 3),
#  ('abandonner_v', 3),
#  ('trésor_n', 3),
#  ('seulement_b', 3),
#  ('compte_n', 3),
#  ('possible_a', 3),
#  ('marteau_n', 3),
#  ('rayonnement_n', 3),
#  ('troisième_a', 3),
#  ('décidément_b', 3),
#  ('lune_n', 3),
#  ('métier_n', 3),
#  ('remettre_v', 3),
#  ('pencher_v', 3),
#  ('toilette_n', 3),
#  ('jeune_a', 3),
#  ('cheveu_n', 3),
#  ('debout_a', 3),
#  ('réflexion_n', 3),
#  ('doigt_n', 3),
#  ('rester_v', 3),
#  ('lourd_n', 3),
#  ('regretter_v', 3),
#  ('frapper_v', 3),
#  ('autorité_n', 3),
#  ('deviner_v', 3),
#  ('respirer_v', 3),
#  ('effet_n', 3),
#  ('hermine_n', 3),
#  ('naïf_a', 3),
#  ('endroit_n', 3),
#  ('danser_v', 3),
#  ('tort_n', 3),
#  ('serrer_v', 3),
#  ('doux_n', 3),
#  ('assez_b', 3),
#  ('importance_n', 3),
#  ('vingt_n', 3),
#  ('musique_n', 3),
#  ('rencontrer_v', 3),
#  ('griffe_n', 3),
#  ('troupeau_n', 3),
#  ('régner_v', 3),
#  ('2_n', 3),
#  ('côté_n', 3),
#  ('parvenir_v', 3),
#  ('renoncer_v', 3),
#  ('écorce_n', 3),
#  ('arbre_n', 3),
#  ('fatigue_n', 3),
#  ('éprouver_v', 3),
#  ('promener_v', 3),
#  ('lentement_b', 3),
#  ('droit_n', 3),
#  ('jeter_v', 3),
#  ('papier_n', 3),
#  ('gagner_v', 3),
#  ('moins_b', 3),
#  ('ville_n', 3),
#  ('craindre_v', 3),
#  ('représenter_v', 3),
#  ('chaise_n', 3),
#  ('assister_v', 3),
#  ('pétale_n', 3),
#  ('change_n', 3),
#  ('fragile_a', 3),
#  ('moteur_n', 3),
#  ('déranger_v', 3),
#  ('rite_n', 3),
#  ('égarer_v', 3),
#  ('quarante_n', 3),
#  ('acheter_v', 3),
#  ('gronder_v', 3),
#  ('rendre_v', 3),
#  ('soulever_v', 3),
#  ('arracher_v', 3),
#  ('chasser_v', 3),
#  ('confier_v', 3),
#  ('simplement_b', 3),
#  ('magnifique_a', 3),
#  ('rentrer_v', 3),
#  ('tout_n', 3),
#  ('fatiguer_v', 3),
#  ('malheureusement_b', 3),
#  ('village_n', 3),
#  ('mystérieux_a', 3),
#  ('as_n', 3),
#  ('justement_b', 3),
#  ('mauvais_a', 3),
#  ('semaine_n', 3),
#  ('douceur_n', 3),
#  ('arroser_v', 3),
#  ('chiffre_n', 3),
#  ('oser_v', 3),
#  ('stupéfait_a', 3),
#  ('intéresser_v', 3),
#  ('activité_n', 3),
#  ('gravement_b', 3),
#  ('autour_b', 3),
#  ('écho_n', 3),
#  ('explication_n', 3),
#  ('aussitôt_b', 3),
#  ('addition_n', 3),
#  ('tousser_v', 3),
#  ('France_n', 3),
#  ('panne_n', 3),
#  ('enfermer_v', 3),
#  ('astronome_n', 3),
#  ('problème_n', 3),
#  ('véritable_a', 3),
#  ('jardin_n', 3),
#  ('corps_n', 3),
#  ('installer_v', 3),
#  ('grâce_n', 3),
#  ('essentiel_n', 3),
#  ('détail_n', 3),
#  ('refaire_v', 3),
#  ('marche_n', 3),
#  ('bête_n', 3),
#  ('dernier_a', 3),
#  ('éclairer_v', 3),
#  ('fleuve_n', 3),
#  ('éclater_v', 2),
#  ('sauter_v', 2),
#  ('étonner_v', 2),
#  ('forêt_n', 2),
#  ('fleurir_v', 2),
#  ('étrange_a', 2),
#  ('régulièrement_b', 2),
#  ('miel_n', 2),
#  ('cou_n', 2),
#  ('jeu_n', 2),
#  ('sorte_n', 2),
#  ('nord_n', 2),
#  ('tourner_v', 2),
#  ("s'enfuir_v", 2),
#  ('milieu_n', 2),
#  ('Afrique_n', 2),
#  ('oreille_n', 2),
#  ('admirateur_n', 2),
#  ("États-Unis_d'Amérique_n", 2),
#  ('pardon_n', 2),
#  ('champ_n', 2),
#  ('haut_a', 2),
#  ('tonnerre_n', 2),
#  ('sourire_v', 2),
#  ('révéler_v', 2),
#  ('fabriquer_v', 2),
#  ('décider_v', 2),
#  ('fenêtre_n', 2),
#  ('hausser_v', 2),
#  ('prochain_a', 2),
#  ('sourire_n', 2),
#  ('rose_a', 2),
#  ('tranquille_a', 2),
#  ('risque_n', 2),
#  ('entrer_v', 2),
#  ('collection_n', 2),
#  ('lancer_v', 2),
#  ('grave_a', 2),
#  ('condition_n', 2),
#  ('Noël_n', 2),
#  ('exécuter_v', 2),
#  ('chenille_n', 2),
#  ('pardonner_v', 2),
#  ('achever_v', 2),
#  ('front_n', 2),
#  ('atteindre_v', 2),
#  ('apparition_n', 2),
#  ('ravissant_a', 2),
#  ('soupir_n', 2),
#  ('sens_n', 2),
#  ('merveilleux_a', 2),
#  ('beauté_n', 2),
#  ('frais_a', 2),
#  ('puissant_a', 2),
#  ('travers_n', 2),
#  ('confus_a', 2),
#  ('saharien_n', 2),
#  ('demain_b', 2),
#  ('manteau_n', 2),
#  ('moquer_v', 2),
#  ('agiter_v', 2),
#  ('sud_n', 2),
#  ('partir_v', 2),
#  ('bouger_v', 2),
#  ('malheureux_a', 2),
#  ('monder_v', 2),
#  ('lendemain_n', 2),
#  ('par_n', 2),
#  ('champignon_n', 2),
#  ('mordre_v', 2),
#  ('faim_n', 2),
#  ('décrire_v', 2),
#  ('près_b', 2),
#  ('humilier_v', 2),
#  ('condamner_v', 2),
#  ('cinquième_a', 2),
#  ('douze_n', 2),
#  ('visiter_v', 2),
#  ('toucher_v', 2),
#  ('hum_n', 2),
#  ('milliard_n', 2),
#  ('ridicule_a', 2),
#  ('vider_v', 2),
#  ('supporter_v', 2),
#  ('véritablement_b', 2),
#  ('roc_n', 2),
#  ('sentiment_n', 2),
#  ('embaumer_v', 2),
#  ('tâche_n', 2),
#  ('horreur_n', 2),
#  ('éruption_n', 2),
#  ('éclat_n', 2),
#  ('compter_v', 2),
#  ('rare_a', 2),
#  ('se_hâter_v', 2),
#  ('lien_n', 2),
#  ('vas_n', 2),
#  ('te_n', 2),
#  ('amérique_n', 2),
#  ('armée_n', 2),
#  ('modestement_b', 2),
#  ('jeudi_n', 2),
#  ('surveiller_v', 2),
#  ('autrefois_b', 2),
#  ('demi_n', 2),
#  ('couler_v', 2),
#  ('chagrin_n', 2),
#  ('interrompre_v', 2),
#  ('déjeuner_v', 2),
#  ('pied_n', 2),
#  ('pôle_n', 2),
#  ('bouteille_n', 2),
#  ('là-bas_b', 2),
#  ('façon_n', 2),
#  ('ministre_n', 2),
#  ('ordinaire_a', 2),
#  ('rat_n', 2),
#  ('songer_v', 2),
#  ('chant_n', 2),
#  ('conséquemment_b', 2),
#  ('serré_a', 2),
#  ('larme_n', 2),
#  ('flâner_v', 2),
#  ('compliqué_a', 2),
#  ('mentir_v', 2),
#  ('absurde_n', 2),
#  ('favorable_a', 2),
#  ('pas_n', 2),
#  ('rouge_a', 2),
#  ('démonstration_n', 2),
#  ('turc_a', 2),
#  ('regret_n', 2),
#  ('nom_n', 2),
#  ('raison_n', 2),
#  ('soigneusement_b', 2),
#  ('grandiose_a', 2),
#  ('un_n', 2),
#  ('exercice_n', 2),
#  ('jaune_a', 2),
#  ('quinze_n', 2),
#  ('machine_n', 2),
#  ('plein_a', 2),
#  ('tolérer_v', 2),
#  ('timidement_b', 2),
#  ('instant_n', 2),
#  ('chute_n', 2),
#  ('éternel_a', 2),
#  ('lampe_n', 2),
#  ('cueillir_v', 2),
#  ('huit_n', 2),
#  ('cacher_v', 2),
#  ('tourmenter_v', 2),
#  ('racine_n', 2),
#  ('soucieux_a', 2),
#  ('cheville_n', 2),
#  ('mélancolique_a', 2),
#  ('plante_n', 2),
#  ('enquête_n', 2),
#  ('amusant_a', 2),
#  ('énorme_a', 2),
#  ('image_n', 2),
#  ('agacer_v', 2),
#  ('lèvre_n', 2),
#  ('télescope_n', 2),
#  ('retrouver_v', 2),
#  ('catastrophe_n', 2),
#  ('recommencer_v', 2),
#  ('reste_n', 2),
#  ('occupation_n', 2),
#  ('venin_n', 2),
#  ('moralité_n', 2),
#  ('retourner_v', 2),
#  ('portrait_n', 2),
#  ('journée_n', 2),
#  ('disparition_n', 2),
#  ('grammaire_n', 2),
#  ('sir_n', 2),
#  ('sûrement_b', 2),
#  ('genou_n', 2),
#  ('univers_n', 2),
#  ('encombrer_v', 2),
#  ('au-dessus_b', 2),
#  ('peuple_n', 2),
#  ('mouvement_n', 2),
#  ('gens_n', 2),
#  ('rosier_n', 2),
#  ('chine_n', 2),
#  ('réputation_n', 2),
#  ('gémir_v', 2),
#  ('chapitre_b', 2),
#  ('avaler_v', 2),
#  ('promesse_n', 2),
#  ('justice_n', 2),
#  ('menacer_v', 2),
#  ('surtout_b', 2),
#  ('presser_v', 2),
#  ('plaindre_v', 2),
#  ('geste_n', 2),
#  ('drame_n', 2),
#  ('confiance_n', 2),
#  ('envie_n', 2),
#  ('courant_n', 2),
#  ('fournir_v', 2),
#  ('dorer_v', 2),
#  ('voyageur_n', 2),
#  ('corne_n', 2),
#  ('ennuyer_v', 2),
#  ('laisse_n', 2),
#  ('inutile_a', 2),
#  ('aider_v', 2),
#  ('costume_n', 2),
#  ('absurde_a', 2),
#  ('peintre_n', 2),
#  ('illuminer_v', 2),
#  ('rêvasser_v', 2),
#  ('pousser_v', 2),
#  ('protéger_v', 2),
#  ('crier_v', 2),
#  ('présence_n', 2),
#  ('anniversaire_n', 2),
#  ('absolu_a', 2),
#  ('rejoindre_v', 2),
#  ('doute_n', 2),
#  ('carrière_n', 2),
#  ('verre_n', 2),
#  ('choisir_v', 2),
#  ('créer_v', 2),
#  ('soudain_b', 2),
#  ('abri_n', 2),
#  ('neige_n', 2),
#  ('loger_v', 2),
#  ('quatrième_a', 2),
#  ('réponse_n', 2),
#  ('plonger_v', 2),
#  ('informer_v', 2),
#  ('certain_a', 1),
#  ('trône_n', 1),
#  ('acte_n', 1),
#  ('ébaucher_v', 1),
#  ('orgueil_n', 1),
#  ('pommier_n', 1),
#  ('fou_n', 1),
#  ('brûler_v', 1),
#  ('patience_n', 1),
#  ('régler_v', 1),
#  ('enrouler_v', 1),
#  ('fidèle_n', 1),
#  ('verser_v', 1),
#  ('modeste_a', 1),
#  ('irriter_v', 1),
#  ('courage_n', 1),
#  ('dangereux_a', 1),
#  ('résoudre_v', 1),
#  ('débarrasser_v', 1),
#  ('efforcer_v', 1),
#  ('frotter_v', 1),
#  ('ballet_n', 1),
#  ('nez_n', 1),
#  ('rhume_n', 1),
#  ('évasion_n', 1),
#  ('outil_n', 1),
#  ('mètre_n', 1),
#  ('rayonner_v', 1),
#  ('urgence_n', 1),
#  ('rêver_v', 1),
#  ('aisément_b', 1),
#  ('confondre_v', 1),
#  ('vacance_n', 1),
#  ('souffrir_v', 1),
#  ('annoncer_v', 1),
#  ('animer_v', 1),
#  ('vivant_n', 1),
#  ('louange_n', 1),
#  ('sauvage_n', 1),
#  ('tendresse_n', 1),
#  ('souffler_v', 1),
#  ('chou_n', 1),
#  ('goutte_n', 1),
#  ('germer_v', 1),
#  ('royaume_n', 1),
#  ('résister_v', 1),
#  ('bouton_n', 1),
#  ('hisser_v', 1),
#  ('soupirer_v', 1),
#  ('inconvénient_n', 1),
#  ('astronomie_n', 1),
#  ('vendre_v', 1),
#  ('feuille_n', 1),
#  ('radis_n', 1),
#  ('anéantir_v', 1),
#  ('pain_n', 1),
#  ('mémoire_n', 1),
#  ('patient_n', 1),
#  ('questionner_v', 1),
#  ('course_n', 1),
#  ('politique_n', 1),
#  ('courir_v', 1),
#  ('finir_v', 1),
#  ('contraire_a', 1),
#  ('pourtant_b', 1),
#  ('abeille_n', 1),
#  ('définitivement_b', 1),
#  ('lire_v', 1),
#  ('attache_n', 1),
#  ('réparation_n', 1),
#  ('élégant_a', 1),
#  ('mécanicien_n', 1),
#  ('traiter_v', 1),
#  ('court_a', 1),
#  ('boîte_n', 1),
#  ('banque_n', 1),
#  ('tempe_n', 1),
#  ('confrère_n', 1),
#  ('attention_n', 1),
#  ('soigner_v', 1),
#  ('trou_n', 1),
#  ('21_n', 1),
#  ('Arizona_n', 1),
#  ('portée_n', 1),
#  ('colombe_n', 1),
#  ('franc_n', 1),
#  ('foudre_n', 1),
#  ('cuir_n', 1),
#  ('cramoisi_a', 1),
#  ('orgueilleuse_a', 1),
#  ('proie_n', 1),
#  ('miraculeux_a', 1),
#  ('révolution_n', 1),
#  ('géranium_n', 1),
#  ('sagesse_n', 1),
#  ('intelligence_n', 1),
#  ('gros_n', 1),
#  ('immobile_a', 1),
#  ('entraîner_v', 1),
#  ('demeurer_v', 1),
#  ('science_n', 1),
#  ('Europe_n', 1),
#  ('reproche_n', 1),
#  ('avis_n', 1),
#  ('précis_a', 1),
#  ('gérer_v', 1),
#  ('poupée_n', 1),
#  ('naufragé_n', 1),
#  ('rond_a', 1),
#  ('meilleur_a', 1),
#  ('golf_n', 1),
#  ('opinion_n', 1),
#  ('bâillement_n', 1),
#  ('perplexe_a', 1),
#  ('mal_b', 1),
#  ('anneau_n', 1),
#  ('mépriser_v', 1),
#  ('jungle_n', 1),
#  ('nul_a', 1),
#  ('laid_a', 1),
#  ('injuste_a', 1),
#  ('Russie_n', 1),
#  ('fidélité_n', 1),
#  ('croître_b', 1),
#  ('installation_n', 1),
#  ('intérêt_n', 1),
#  ('lueur_n', 1),
#  ('église_n', 1),
#  ('dix_n', 1),
#  ('langage_n', 1),
#  ('rancune_n', 1),
#  ('prêt_a', 1),
#  ('fouiller_v', 1),
#  ('interdire_v', 1),
#  ('épuiser_v', 1),
#  ('peupler_v', 1),
#  ('aborder_v', 1),
#  ('trier_v', 1),
#  ('mouche_n', 1),
#  ('sec_a', 1),
#  ('mille_a', 1),
#  ('entrée_n', 1),
#  ('digestion_n', 1),
#  ('ancien_a', 1),
#  ('quelconque_a', 1),
#  ('Vénus_n', 1),
#  ('préférer_v', 1),
#  ('pensée_n', 1),
#  ('morsure_n', 1),
#  ('secouer_v', 1),
#  ('rouillé_a', 1),
#  ('épargne_n', 1),
#  ('imagination_n', 1),
#  ('émouvant_a', 1),
#  ('aliment_n', 1),
#  ('paresseux_n', 1),
#  ('dépendre_v', 1),
#  ('isolé_a', 1),
#  ('neuf_a', 1),
#  ('respecter_v', 1),
#  ('réchauffer_v', 1),
#  ('pousse_n', 1),
#  ('tailler_v', 1),
#  ('fond_n', 1),
#  ('arrosoir_n', 1),
#  ('ai_n', 1),
#  ('considérable_a', 1),
#  ('préambule_n', 1),
#  ('vide_n', 1),
#  ('ira_n', 1),
#  ('réfléchir_v', 1),
#  ('cesser_v', 1),
#  ('évidemment_b', 1),
#  ('traîne_n', 1),
#  ('droite_n', 1),
#  ('minuscule_n', 1),
#  ('étudier_v', 1),
#  ('sot_n', 1),
#  ('froid_a', 1),
#  ('choquer_v', 1),
#  ('approche_n', 1),
#  ('but_n', 1),
#  ('mélange_n', 1),
#  ('risquer_v', 1),
#  ('commode_a', 1),
#  ('glacé_a', 1),
#  ('toux_n', 1),
#  ('Sibérie_n', 1),
#  ('vert_a', 1),
#  ('parfait_a', 1),
#  ('perforer_v', 1),
#  ('sixième_a', 1),
#  ('arrivée_n', 1),
#  ('hanneton_n', 1),
#  ('échange_n', 1),
#  ('universel_n', 1),
#  ('population_n', 1),
#  ('dieu_n', 1),
#  ('heureusement_b', 1),
#  ('négliger_v', 1),
#  ('dresser_v', 1),
#  ('coulisse_n', 1),
#  ('rapide_n', 1),
#  ('dimension_n', 1),
#  ('souhaiter_v', 1),
#  ('12_n', 1),
#  ('chauffer_v', 1),
#  ('moindre_a', 1),
#  ('fier_v', 1),
#  ('vanité_n', 1),
#  ('immensité_n', 1),
#  ('attentivement_b', 1),
#  ('vigne_n', 1),
#  ('bouche_n', 1),
#  ('fatigant_a', 1),
#  ('23_n', 1),
#  ('ruine_n', 1),
#  ('crépuscule_n', 1),
#  ('halte_n', 1),
#  ('malade_a', 1),
#  ('scène_n', 1),
#  ('énormément_b', 1),
#  ('rhumatisme_n', 1),
#  ('prix_n', 1),
#  ('juge_n', 1),
#  ('regard_n', 1),
#  ('remords_n', 1),
#  ('entasser_v', 1),
#  ('peser_v', 1),
#  ('contradictoire_a', 1),
#  ('aveugle_a', 1),
#  ('doré_a', 1),
#  ('fermement_b', 1),
#  ('espèce_n', 1),
#  ('pays_n', 1),
#  ('européen_a', 1),
#  ('enjambée_n', 1),
#  ('pli_n', 1),
#  ('vierge_n', 1),
#  ('forme_n', 1),
#  ('entier_a', 1),
#  ('camarade_n', 1),
#  ('connaissance_n', 1),
#  ('aventure_n', 1),
#  ('jambe_n', 1),
#  ('nombreux_a', 1),
#  ('14_n', 1),
#  ('mouiller_v', 1),
#  ('pauvre_n', 1),
#  ('avance_n', 1),
#  ('simplicité_n', 1),
#  ('fête_n', 1),
#  ('parfois_b', 1),
#  ('placer_v', 1),
#  ('améliorer_v', 1),
#  ...]

# %%
special_set = set()
for word in wolf_freq:
    if word[:2] == '__':
        special_set.add(word)

# %%
special_set
# Out:
# {'__GIVEN_FUNCTIONAL__',
#  '__MANUAL_REJ__',
#  '__MATCHED_FUNCTIONAL__',
#  '__UNMATECHED__'}

# %%
freq_valid = 0
freq_rejected = 0
freq_unaccounted = wolf_freq['__UNMATECHED__']
for word in wolf_freq:
    if word[:2] != '__':
        freq_valid += wolf_freq[word]
    else:
        freq_rejected += wolf_freq[word]

# %%
freq_valid, freq_rejected, freq_unaccounted
# Out:
# (6860, 12417, 181)

# %%
overwrite_check = True

if overwrite_check:
    output_file = open('lpp_tuned_wolf_vocabulary.txt', mode='w+')
    output_file.write('\n'.join(list(set(wolf_freq).difference(special_set))))
    output_file.close()
